# %% [markdown]
# # CO2 Neutral Structures
#
# ## Differential equation for composite interaction
#
# ```{figure} Figures/FreeBodyDiagram_CompositeInteraction.png
# ---
# name: FBD_CompositeInteraction
# wdith: 80%
# align: middle
# ---
# Free body diagram composite interaction
# ```
#
# ```{math}
# :label: eq:verforceeq
# \frac{dV}{dx} = -q
# ```
#
# ```{math}
# :label: eq:horforceeq
# N_1 + N_2 = 0
# ```
#
# ```{math}
# :label: eq:benmomeq
# M = M_1 + M_2 - N_1 /cdot r
# ```
#
# ```{math}
# :label: eq:vershearforceeq
# V = \frac{dM}{dx}
# ```
#
# ```{math}
# :label: eq:longshearforceflow
# V_s = K \cdot s = -\frac{dN_1}{dx} = \frac{dN_2}{dx}
# ```
